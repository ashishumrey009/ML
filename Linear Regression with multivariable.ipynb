# %%
import pandas as pd

# %%
data= pd.read_csv("E:\MLNEW _BTM\ex1data2.txt",header=None,names=['Size','BedroomNo','Price'])

# %%
data.head()
# Out:
#    Size  BedroomNo   Price
# 0  2104          3  399900
# 1  1600          3  329900
# 2  2400          3  369000
# 3  1416          2  232000
# 4  3000          4  539900

# %%
data.describe()
# Out:
#               Size  BedroomNo          Price
# count    47.000000  47.000000      47.000000
# mean   2000.680851   3.170213  340412.659574
# std     794.702354   0.760982  125039.899586
# min     852.000000   1.000000  169900.000000
# 25%    1432.000000   3.000000  249900.000000
# 50%    1888.000000   3.000000  299900.000000
# 75%    2269.000000   4.000000  384450.000000
# max    4478.000000   5.000000  699900.000000

# %%
data2 =(data.data.mean())/data.std()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-ce1161a6a471> in <module>()
# ----> 1 data2 =(data.data.mean())/data.std()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'data'

# %%
data.head()
# Out:
#    Size  BedroomNo   Price
# 0  2104          3  399900
# 1  1600          3  329900
# 2  2400          3  369000
# 3  1416          2  232000
# 4  3000          4  539900

# %%
data2 =(data-data.mean())/data.std()

# %%
data.head()
# Out:
#    Size  BedroomNo   Price
# 0  2104          3  399900
# 1  1600          3  329900
# 2  2400          3  369000
# 3  1416          2  232000
# 4  3000          4  539900

# %%
data2.head()
# Out:
#        Size  BedroomNo     Price
# 0  0.130010  -0.223675  0.475747
# 1 -0.504190  -0.223675 -0.084074
# 2  0.502476  -0.223675  0.228626
# 3 -0.735723  -1.537767 -0.867025
# 4  1.257476   1.090417  1.595389

# %%
data2.describe()
# Out:
#                Size     BedroomNo         Price
# count  4.700000e+01  4.700000e+01  4.700000e+01
# mean   1.889741e-17  2.279500e-16 -8.031401e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.445423e+00 -2.851859e+00 -1.363666e+00
# 25%   -7.155897e-01 -2.236752e-01 -7.238702e-01
# 50%   -1.417900e-01 -2.236752e-01 -3.239979e-01
# 75%    3.376348e-01  1.090417e+00  3.521863e-01
# max    3.117292e+00  2.404508e+00  2.874981e+00

# %%
def computeCost(X,y,theta):
    inner = np.power(((X*theta.T)-y),2)
    return np.sum(inner)/(2*len(X))

# %%
data2
# Out:
#         Size  BedroomNo     Price
# 0   0.130010  -0.223675  0.475747
# 1  -0.504190  -0.223675 -0.084074
# 2   0.502476  -0.223675  0.228626
# 3  -0.735723  -1.537767 -0.867025
# 4   1.257476   1.090417  1.595389
# 5  -0.019732   1.090417 -0.323998
# 6  -0.587240  -0.223675 -0.204036
# 7  -0.721881  -0.223675 -1.130948
# 8  -0.781023  -0.223675 -1.026973
# 9  -0.637573  -0.223675 -0.783051
# 10 -0.076357   1.090417 -0.803053
# 11 -0.000857  -0.223675  0.052682
# 12 -0.139273  -0.223675 -0.083283
# 13  3.117292   2.404508  2.874981
# 14 -0.921956  -0.223675 -0.643896
# 15  0.376643   1.090417  0.875619
# 16 -0.856523  -1.537767 -0.323998
# 17 -0.962223  -0.223675 -1.123743
# 18  0.765468   1.090417  1.276275
# 19  1.296484   1.090417  2.068039
# 20 -0.294048  -0.223675 -0.699878
# 21 -0.141790  -1.537767 -0.683083
# 22 -0.499157  -0.223675 -0.779852
# 23 -0.048673   1.090417 -0.643896
# 24  2.377392  -0.223675  1.867303
# 25 -1.133356  -0.223675 -0.723870
# ...

# %%
data2.insert(0,'Ones',1)

# %%
data2
# Out:
#     Ones      Size  BedroomNo     Price
# 0      1  0.130010  -0.223675  0.475747
# 1      1 -0.504190  -0.223675 -0.084074
# 2      1  0.502476  -0.223675  0.228626
# 3      1 -0.735723  -1.537767 -0.867025
# 4      1  1.257476   1.090417  1.595389
# 5      1 -0.019732   1.090417 -0.323998
# 6      1 -0.587240  -0.223675 -0.204036
# 7      1 -0.721881  -0.223675 -1.130948
# 8      1 -0.781023  -0.223675 -1.026973
# 9      1 -0.637573  -0.223675 -0.783051
# 10     1 -0.076357   1.090417 -0.803053
# 11     1 -0.000857  -0.223675  0.052682
# 12     1 -0.139273  -0.223675 -0.083283
# 13     1  3.117292   2.404508  2.874981
# 14     1 -0.921956  -0.223675 -0.643896
# 15     1  0.376643   1.090417  0.875619
# 16     1 -0.856523  -1.537767 -0.323998
# 17     1 -0.962223  -0.223675 -1.123743
# 18     1  0.765468   1.090417  1.276275
# 19     1  1.296484   1.090417  2.068039
# 20     1 -0.294048  -0.223675 -0.699878
# 21     1 -0.141790  -1.537767 -0.683083
# ...

# %%
X = data2.iloc[:,0:3]

# %%
X
# Out:
#     Ones  Size  BedroomNo
# 0      1  2104          3
# 1      1  1600          3
# 2      1  2400          3
# 3      1  1416          2
# 4      1  3000          4
# 5      1  1985          4
# 6      1  1534          3
# 7      1  1427          3
# 8      1  1380          3
# 9      1  1494          3
# 10     1  1940          4
# 11     1  2000          3
# 12     1  1890          3
# 13     1  4478          5
# 14     1  1268          3
# 15     1  2300          4
# 16     1  1320          2
# 17     1  1236          3
# 18     1  2609          4
# 19     1  3031          4
# 20     1  1767          3
# 21     1  1888          2
# 22     1  1604          3
# 23     1  1962          4
# 24     1  3890          3
# 25     1  1100          3
# 26     1  1458          3
# 27     1  2526          3
# 28     1  2200          3
# 29     1  2637          3
# 30     1  1839          2
# 31     1  1000          1
# 32     1  2040          4
# 33     1  3137          3
# ...

# %%
y = data2.iloc[:,3:4]

# %%
y
# Out:
#        Price
# 0   0.475747
# 1  -0.084074
# 2   0.228626
# 3  -0.867025
# 4   1.595389
# 5  -0.323998
# 6  -0.204036
# 7  -1.130948
# 8  -1.026973
# 9  -0.783051
# 10 -0.803053
# 11  0.052682
# 12 -0.083283
# 13  2.874981
# 14 -0.643896
# 15  0.875619
# 16 -0.323998
# 17 -1.123743
# 18  1.276275
# 19  2.068039
# 20 -0.699878
# 21 -0.683083
# 22 -0.779852
# 23 -0.643896
# 24  1.867303
# 25 -0.723870
# 26  0.992382
# 27  1.028370
# 28  1.076355
# 29 -0.323998
# 30  0.075875
# 31 -1.363666
# 32 -0.204036
# 33  1.915287
# 34 -0.435962
# 35 -0.723870
# 36 -0.883819
# 37  0.036687
# 38  1.668166
# 39 -0.427165
# 40  0.224627
# 41 -0.084074
# 42 -0.211234
# 43 -0.331196
# 44 -1.283692
# 45 -0.323998
# 46 -0.807044

# %%
X = np.matrix(X)
y = np.matrix(y)
theta = np.matrix(np.array([0,0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-1cabf5654d42> in <module>()
# ----> 1 X = np.matrix(X)
#       2 y = np.matrix(y)
#       3 theta = np.matrix(np.array([0,0]))
#
# NameError: name 'np' is not defined

# %%
import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
X = np.matrix(X)
y = np.matrix(y)
theta = np.matrix(np.array([0,0,0]))

# %%
computeCost(X,y,theta)
# Out:
# 0.48936170212765967

# %%
X.shape,y.shape,theta.shape
# Out:
# ((47, 3), (47, 1), (1, 3))

# %%
computeCost(X,y,theta)
# Out:
# 0.48936170212765967

# %%
def gradientDescent(X,y,theta,alpha,iters):
    temp = np.matrix(np.zeros(theta.shape))
    parameters = 3
    cost = np.zeros(iters)
    for i in range(iters):
        error = (X*theta.T)-y
        for j in range(parameters):
            term= np.multiply(error,X[:,j])
            temp[0,j] = theta[0,j] - ((alpha/len(X)) * np.sum(term))
        theta =  temp
        cost[i] = computeCost(X,y,theta)
    return theta,cost

# %%
t,c =gradientDescent(X,y,0.01,100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-f792cda09936> in <module>()
# ----> 1 t,c =gradientDescent(X,y,0.01,100)
#
# TypeError: gradientDescent() missing 1 required positional argument: 'iters'

# %%
t,c =gradientDescent(X,y,theta,0.01,1000)

# %%
t,c
# Out:
# (matrix([[ -1.03191687e-16,   8.78503652e-01,  -4.69166570e-02]]),
#  array([ 0.4805491 ,  0.47198588,  0.46366462,  0.45557814,  0.44771948,
#          0.44008189,  0.43265881,  0.42544389,  0.41843096,  0.41161404,
#          0.40498735,  0.39854524,  0.39228228,  0.38619317,  0.38027278,
#          0.37451612,  0.36891839,  0.36347488,  0.35818107,  0.35303254,
#          0.34802503,  0.34315438,  0.33841659,  0.33380775,  0.32932407,
#          0.3249619 ,  0.32071767,  0.31658793,  0.31256934,  0.30865863,
#          0.30485268,  0.30114841,  0.29754287,  0.29403318,  0.29061655,
#          0.28729027,  0.28405173,  0.28089837,  0.27782772,  0.27483739,
#          0.27192505,  0.26908845,  0.26632541,  0.26363379,  0.26101154,
#          0.25845666,  0.25596722,  0.25354134,  0.25117719,  0.248873  ,
#          0.24662705,  0.24443769,  0.24230329,  0.24022228,  0.23819315,
#          0.23621442,  0.23428466,  0.23240248,  0.23056652,  0.22877549,
# ...

# %%
c[-1]
# Out:
# 0.13070336960771892

# %%
t
# Out:
# matrix([[ -1.03191687e-16,   8.78503652e-01,  -4.69166570e-02]])

# %%
fig,ax=plt.subplots(figsize=(12,8))
ax.plot(np.arange(1000),c,'r')

# %%
x1_final=[]
x2_final=[]
x1_plot = np.linespace(-1,1,1000)
x2_plot = np.linespace(-1,1,1000)
for i in x1_plot:
    for j in x2_plot:
        c= sigmoid(t[0,0]+t[0,1]*j+t[0,2]*(j**2)+t[0,3]*i+t[0,4]*(i*j)+t[0,5]*(i**2))
        if (c>=0.49 and c<=0.51):
            x1_final.append(i)
            x2_final.append(j)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cf8ed306b7a0> in <module>()
#       1 x1_final=[]
#       2 x2_final=[]
# ----> 3 x1_plot = np.linespace(-1,1,1000)
#       4 x2_plot = np.linespace(-1,1,1000)
#       5 for i in x1_plot:
#
# NameError: name 'np' is not defined

# %%
x2_final=[]
x2_final = np.linspace(-1,1,100)
x1_plot = np.linspace(-1,1,1000)
for i in x1_plot:
    for j in x2_plot:
        c= sigmoid(t[0,0]+t[0,1]*j+t[0,2]*(j**2)+t[0,3]*i+t[0,4]*(i*j)+t[0,5]*(i**2))
        if (c>=0.49 and c<=0.51):
            x1_final.append(i)
            x2_final.append(j)
