# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data= pd.read_csv("E:\MLNEW _BTM\ex1data1.txt",header=None,names=['Population','Profit'])

# %%
data.head()
# Out:
#    Population   Profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233

# %%
data.plot(kind='scatter', x='Population',y='Profit',figsize(12,8))
# Out:
#   File "<ipython-input-4-4bc4beb282fa>", line 1
#     data.plot(kind='scatter', x='Population',y='Profit',figsize(12,8))
#                                                        ^
# SyntaxError: positional argument follows keyword argument

# %%
data.plot(kind='scatter', x='Population',y='Profit',figsize(12,8)

# %%
import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
data.plot(kind='scatter', x='Population', y='Profit', figsize=(12,8))

# %%
data.describe()

# %%
def computeCost(X,y,theta):
    inner = np.power(((X*theta.T)-y),2)
    return np.sum(inner)/(2*len(X))

# %%
data

# %%
data.insert(0,'Ones',1)

# %%
data

# %%
X = data.iloc[:,0:2]
y = data.iloc[:,2:3]
X,y
# Out:
# (    Population    Profit
#  0       6.1101  17.59200
#  1       5.5277   9.13020
#  2       8.5186  13.66200
#  3       7.0032  11.85400
#  4       5.8598   6.82330
#  5       8.3829  11.88600
#  6       7.4764   4.34830
#  7       8.5781  12.00000
#  8       6.4862   6.59870
#  9       5.0546   3.81660
#  10      5.7107   3.25220
#  11     14.1640  15.50500
#  12      5.7340   3.15510
#  13      8.4084   7.22580
#  14      5.6407   0.71618
#  15      5.3794   3.51290
#  16      6.3654   5.30480
#  17      5.1301   0.56077
#  18      6.4296   3.65180
#  19      7.0708   5.38930
#  20      6.1891   3.13860
#  21     20.2700  21.76700
#  22      5.4901   4.26300
#  23      6.3261   5.18750
#  24      5.5649   3.08250
#  25     18.9450  22.63800
#  26     12.8280  13.50100
#  27     10.9570   7.04670
#  28     13.1760  14.69200
#  29     22.2030  24.14700
#  ..         ...       ...
#  67     10.2360   7.77540
#  68      5.4994   1.01730
#  69     20.3410  20.99200
# ...

# %%
X = np.matrix(X)
y = np.matrix(y)
theta = np.matrix(np.array([0,0]))
X,y,theta
# Out:
# (matrix([[  6.1101 ,  17.592  ],
#          [  5.5277 ,   9.1302 ],
#          [  8.5186 ,  13.662  ],
#          [  7.0032 ,  11.854  ],
#          [  5.8598 ,   6.8233 ],
#          [  8.3829 ,  11.886  ],
#          [  7.4764 ,   4.3483 ],
#          [  8.5781 ,  12.     ],
#          [  6.4862 ,   6.5987 ],
#          [  5.0546 ,   3.8166 ],
#          [  5.7107 ,   3.2522 ],
#          [ 14.164  ,  15.505  ],
#          [  5.734  ,   3.1551 ],
#          [  8.4084 ,   7.2258 ],
#          [  5.6407 ,   0.71618],
#          [  5.3794 ,   3.5129 ],
#          [  6.3654 ,   5.3048 ],
#          [  5.1301 ,   0.56077],
#          [  6.4296 ,   3.6518 ],
#          [  7.0708 ,   5.3893 ],
#          [  6.1891 ,   3.1386 ],
#          [ 20.27   ,  21.767  ],
#          [  5.4901 ,   4.263  ],
#          [  6.3261 ,   5.1875 ],
#          [  5.5649 ,   3.0825 ],
#          [ 18.945  ,  22.638  ],
#          [ 12.828  ,  13.501  ],
#          [ 10.957  ,   7.0467 ],
# ...

# %%
computeCost
# Out:
# <function __main__.computeCost>

# %%
computeCost(X,y,theta)
# Out:
# 32.072733877455676

# %%
X.shape,theta.shape,y.shape
# Out:
# ((97, 2), (1, 2), (97, 1))

# %%
def gradientDescent(X,y,theta,alpha,iters):
    temp = np.matrix(np.zeros(theta.shape))
    parameters = 2
    cost = np.zeros(iters)
    for i in range(iters):
        error = (X*theta.T)-y
        for j in range(parameters):
            term= np.multiply(error,X[:,j])
            temp[0,j] = theta[0,j] - ((alpha/len(X)) * np.sum(term))
        theta =  temp
        cost[i] = computeCost(X,y,theta)
    return theta,cost

# %%
t,c =gradientDescent(X,y,0.01,100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-f792cda09936> in <module>()
# ----> 1 t,c =gradientDescent(X,y,0.01,100)
#
# TypeError: gradientDescent() missing 1 required positional argument: 'iters'

# %%
t,c =gradientDescent(X,y,0.01,100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-f792cda09936> in <module>()
# ----> 1 t,c =gradientDescent(X,y,0.01,100)
#
# TypeError: gradientDescent() missing 1 required positional argument: 'iters'

# %%
t,c =gradientDescent(X,y,theta,0.01,100)

# %%
t,c =gradientDescent(X,y,0.01,100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-f792cda09936> in <module>()
# ----> 1 t,c =gradientDescent(X,y,0.01,100)
#
# TypeError: gradientDescent() missing 1 required positional argument: 'iters'

# %%
t,c =gradientDescent(X,y,theta,0.01,100000)

# %%
t,c
# Out:
# (matrix([[-0.57655623,  0.85958153]]),
#  array([ 6.73719046,  5.93159357,  5.90115471,  5.89522859,  5.89009494,
#          5.88500416,  5.87993248,  5.87487909,  5.86984391,  5.86482687,
#          5.85982789,  5.85484692,  5.84988389,  5.84493874,  5.8400114 ,
#          5.83510181,  5.8302099 ,  5.82533562,  5.82047889,  5.81563965,
#          5.81081784,  5.8060134 ,  5.80122627,  5.79645638,  5.79170367,
#          5.78696808,  5.78224955,  5.77754801,  5.77286341,  5.76819568,
#          5.76354477,  5.75891061,  5.75429313,  5.7496923 ,  5.74510803,
#          5.74054027,  5.73598897,  5.73145406,  5.72693549,  5.72243319,
#          5.71794711,  5.71347718,  5.70902336,  5.70458558,  5.70016379,
#          5.69575792,  5.69136792,  5.68699373,  5.6826353 ,  5.67829257,
#          5.67396548,  5.66965398,  5.665358  ,  5.6610775 ,  5.65681242,
#          5.6525627 ,  5.64832829,  5.64410913,  5.63990517,  5.63571635,
# ...

# %%
t
# Out:
# matrix([[-0.57655623,  0.85958153]])

# %%
c[-1]
# Out:
# 5.4799755805351129

# %%
t
# Out:
# matrix([[-3.24140214,  1.1272942 ]])

# %%
c
# Out:
# array([ 6.73719046,  5.93159357,  5.90115471,  5.89522859,  5.89009494,
#         5.88500416,  5.87993248,  5.87487909,  5.86984391,  5.86482687,
#         5.85982789,  5.85484692,  5.84988389,  5.84493874,  5.8400114 ,
#         5.83510181,  5.8302099 ,  5.82533562,  5.82047889,  5.81563965,
#         5.81081784,  5.8060134 ,  5.80122627,  5.79645638,  5.79170367,
#         5.78696808,  5.78224955,  5.77754801,  5.77286341,  5.76819568,
#         5.76354477,  5.75891061,  5.75429313,  5.7496923 ,  5.74510803,
#         5.74054027,  5.73598897,  5.73145406,  5.72693549,  5.72243319,
#         5.71794711,  5.71347718,  5.70902336,  5.70458558,  5.70016379,
#         5.69575792,  5.69136792,  5.68699373,  5.6826353 ,  5.67829257,
#         5.67396548,  5.66965398,  5.665358  ,  5.6610775 ,  5.65681242,
#         5.6525627 ,  5.64832829,  5.64410913,  5.63990517,  5.63571635,
#         5.63154261,  5.62738391,  5.6232402 ,  5.6191114 ,  5.61499748,
# ...

# %%
c[-1]
# Out:
# 4.5159555030789136

# %%
t
# Out:
# matrix([[-3.89578082,  1.19303364]])

# %%
c
# Out:
# array([ 6.73719046,  5.93159357,  5.90115471, ...,  4.47697138,
#         4.47697138,  4.47697138])

# %%
c[-1]
# Out:
# 4.4769713759751779

# %%
c[-1]
# Out:
# 4.4769713759751788

# %%
a = np.linspace(data.Population.min(),data.Population.max(),100)

# %%
f = t[0,0] + (t[0,1]*a)
fig,ax=plt.subplots(figsize=(12,8))
ax.plot(a,f,'r',label='Prediction')
ax.scatter(data.Population,data.Profit,label='Training Data')
ax.legend(loc=2)

# %%
fig,ax=plt.subplots(figsize=(12,8))
ax.plot(np.arange(100000),c,'r')
